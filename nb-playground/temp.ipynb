# %%
from branca.colormap import linear

# %%
linear.Accent_03
# Out:
# <svg height="40" width="450"><line x1="0" y1="15" x2="0" y2="27" style="stroke:#7fc97fff;stroke-width:2;" /><line x1="1" y1="15" x2="1" y2="27" style="stroke:#7fc97fff;stroke-width:2;" /><line x1="2" y1="15" x2="2" y2="27" style="stroke:#80c980ff;stroke-width:2;" /><line x1="3" y1="15" x2="3" y2="27" style="stroke:#80c980ff;stroke-width:2;" /><line x1="4" y1="15" x2="4" y2="27" style="stroke:#80c981ff;stroke-width:2;" /><line x1="5" y1="15" x2="5" y2="27" style="stroke:#80c981ff;stroke-width:2;" /><line x1="6" y1="15" x2="6" y2="27" style="stroke:#81c981ff;stroke-width:2;" /><line x1="7" y1="15" x2="7" y2="27" style="stroke:#81c882ff;stroke-width:2;" /><line x1="8" y1="15" x2="8" y2="27" style="stroke:#81c882ff;stroke-width:2;" /><line x1="9" y1="15" x2="9" y2="27" style="stroke:#82c882ff;stroke-width:2;" /><line x1="10" y1="15" x2="10" y2="27" style="stroke:#82c883ff;stroke-width:2;" /><line x1="11" y1="15" x2="11" y2="27" style="stroke:#82c883ff;stroke-width:2;" /><line x1="12" y1=
# ...

# %%
i=0

# %%
i-=1

# %%
a = dir(linear)
i+=1
colormap = getattr(linear, a[i]).scale(
10,100
)
print(a[i])
colormap
# Out:
# RdPu_04
# ...

# %%
len(a)
# Out:
# 299
